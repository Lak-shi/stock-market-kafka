# %%
from kafka import KafkaConsumer
from time import sleep
from json import dumps,loads
import json
from s3fs import S3FileSystem

# %%
consumer = KafkaConsumer(
    'demo_test',
     bootstrap_servers=['3.12.74.181:9092'], #my IP here
    value_deserializer=lambda x: loads(x.decode('utf-8')))

# %%
# for c in consumer:
#     print(c.value)

# %%
# !pip install s3fs
# Out:
# Collecting s3fs
#   Downloading s3fs-2024.6.1-py3-none-any.whl.metadata (1.6 kB)
# Collecting aiobotocore<3.0.0,>=2.5.4 (from s3fs)
#   Downloading aiobotocore-2.13.1-py3-none-any.whl.metadata (22 kB)
# Collecting fsspec==2024.6.1.* (from s3fs)
#   Downloading fsspec-2024.6.1-py3-none-any.whl.metadata (11 kB)
# Collecting aiohttp!=4.0.0a0,!=4.0.0a1 (from s3fs)
#   Downloading aiohttp-3.9.5-cp311-cp311-macosx_11_0_arm64.whl.metadata (7.5 kB)
# Collecting botocore<1.34.132,>=1.34.70 (from aiobotocore<3.0.0,>=2.5.4->s3fs)
#   Downloading botocore-1.34.131-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: wrapt<2.0.0,>=1.10.10 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs) (1.15.0)
# Collecting aioitertools<1.0.0,>=0.5.1 (from aiobotocore<3.0.0,>=2.5.4->s3fs)
#   Downloading aioitertools-0.11.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting aiosignal>=1.1.2 (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs)
#   Downloading aiosignal-1.3.1-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: attrs>=17.3.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (23.1.0)
# Collecting frozenlist>=1.1.1 (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs)
#   Downloading frozenlist-1.4.1-cp311-cp311-macosx_11_0_arm64.whl.metadata (12 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs)
#   Downloading multidict-6.0.5-cp311-cp311-macosx_11_0_arm64.whl.metadata (4.2 kB)
# Collecting yarl<2.0,>=1.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs)
#   Downloading yarl-1.9.4-cp311-cp311-macosx_11_0_arm64.whl.metadata (31 kB)
# Collecting jmespath<2.0.0,>=0.7.1 (from botocore<1.34.132,>=1.34.70->aiobotocore<3.0.0,>=2.5.4->s3fs)
#   Downloading jmespath-1.0.1-py3-none-any.whl.metadata (7.6 kB)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from botocore<1.34.132,>=1.34.70->aiobotocore<3.0.0,>=2.5.4->s3fs) (2.8.2)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from botocore<1.34.132,>=1.34.70->aiobotocore<3.0.0,>=2.5.4->s3fs) (1.26.16)
# Requirement already satisfied: idna>=2.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from yarl<2.0,>=1.0->aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (3.4)
# Requirement already satisfied: six>=1.5 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.34.132,>=1.34.70->aiobotocore<3.0.0,>=2.5.4->s3fs) (1.16.0)
# Downloading s3fs-2024.6.1-py3-none-any.whl (29 kB)
# Downloading fsspec-2024.6.1-py3-none-any.whl (177 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 177.6/177.6 kB 4.0 MB/s eta 0:00:00a 0:00:01
# Downloading aiobotocore-2.13.1-py3-none-any.whl (76 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.9/76.9 kB 7.8 MB/s eta 0:00:00
# Downloading aiohttp-3.9.5-cp311-cp311-macosx_11_0_arm64.whl (390 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 390.2/390.2 kB 7.6 MB/s eta 0:00:00a 0:00:01
# Downloading aioitertools-0.11.0-py3-none-any.whl (23 kB)
# Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Downloading botocore-1.34.131-py3-none-any.whl (12.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 29.4 MB/s eta 0:00:0000:0100:01
# Downloading frozenlist-1.4.1-cp311-cp311-macosx_11_0_arm64.whl (53 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.4/53.4 kB 4.0 MB/s eta 0:00:00
# Downloading multidict-6.0.5-cp311-cp311-macosx_11_0_arm64.whl (30 kB)
# Downloading yarl-1.9.4-cp311-cp311-macosx_11_0_arm64.whl (81 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.2/81.2 kB 5.9 MB/s eta 0:00:00
# Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Installing collected packages: multidict, jmespath, fsspec, frozenlist, aioitertools, yarl, botocore, aiosignal, aiohttp, aiobotocore, s3fs
# Successfully installed aiobotocore-2.13.1 aiohttp-3.9.5 aioitertools-0.11.0 aiosignal-1.3.1 botocore-1.34.131 frozenlist-1.4.1 fsspec-2024.6.1 jmespath-1.0.1 multidict-6.0.5 s3fs-2024.6.1 yarl-1.9.4
#
# [notice] A new release of pip is available: 23.3.1 -> 24.1.2
# [notice] To update, run: pip install --upgrade pip

# %%
s3 = S3FileSystem()

# %%
for count, i in enumerate(consumer):
    print(count)
    print(i.value)
# Out:
# 0
# {'Index': 'NYA', 'Date': '1995-06-02', 'Open': 3029.689941, 'High': 3029.689941, 'Low': 3029.689941, 'Close': 3029.689941, 'Adj Close': 3029.689941, 'Volume': 0.0, 'CloseUSD': 3029.689941}
# 1
# {'Index': 'J203.JO', 'Date': '2019-04-29', 'Open': 58894.19141, 'High': 59012.07813, 'Low': 58561.57813, 'Close': 58662.67969, 'Adj Close': 58662.67969, 'Volume': 0.0, 'CloseUSD': 4106.3875783}
# 2
# {'Index': 'GSPTSE', 'Date': '2011-12-07', 'Open': 12071.90039, 'High': 12167.09961, 'Low': 11997.29981, 'Close': 12148.7002, 'Adj Close': 12148.7002, 'Volume': 23497920000.0, 'CloseUSD': 10083.421165999998}
# 3
# {'Index': '399001.SZ', 'Date': '2007-03-09', 'Open': 8269.349609, 'High': 8287.69043, 'Low': 8103.319824, 'Close': 8146.439941, 'Adj Close': 8146.348633, 'Volume': 83000.0, 'CloseUSD': 1303.43039056}
# 4
# {'Index': 'NYA', 'Date': '1968-04-30', 'Open': 576.159973, 'High': 576.159973, 'Low': 576.159973, 'Close': 576.159973, 'Adj Close': 576.159973, 'Volume': 0.0, 'CloseUSD': 576.159973}
# 5
# {'Index': 'N225', 'Date': '1985-03-01', 'Open': 12412.13965, 'High': 12412.13965, 'Low': 12412.13965, 'Close': 12412.13965, 'Adj Close': 12412.13965, 'Volume': 0.0, 'CloseUSD': 124.1213965}
# 6
# {'Index': '000001.SS', 'Date': '2005-08-09', 'Open': 1139.121948, 'High': 1152.939941, 'Low': 1130.584961, 'Close': 1152.534058, 'Adj Close': 1152.534058, 'Volume': 27200.0, 'CloseUSD': 184.40544928}
# 7
# {'Index': 'HSI', 'Date': '2002-02-08', 'Open': 10441.19043, 'High': 10526.75, 'Low': 10421.48047, 'Close': 10518.99023, 'Adj Close': 10518.99023, 'Volume': 259185400.0, 'CloseUSD': 1367.4687299}
# 8
# {'Index': 'N225', 'Date': '2014-01-29', 'Open': 15164.33984, 'High': 15383.91016, 'Low': 15159.91992, 'Close': 15383.91016, 'Adj Close': 15383.91016, 'Volume': 164800000.0, 'CloseUSD': 153.8391016}
# 9
# {'Index': 'SSMI', 'Date': '2011-04-14', 'Open': 6337.859863, 'High': 6391.439941, 'Low': 6337.859863, 'Close': 6357.029785, 'Adj Close': 6357.029785, 'Volume': 51452600.0, 'CloseUSD': 7056.3030613500005}
# 10
# {'Index': '000001.SS', 'Date': '2007-02-05', 'Open': 2658.073975, 'High': 2672.352051, 'Low': 2610.331055, 'Close': 2612.537109, 'Adj Close': 2612.537109, 'Volume': 69200.0, 'CloseUSD': 418.00593744}
# 11
# {'Index': 'HSI', 'Date': '1996-05-24', 'Open': 11021.79981, 'High': 11058.40039, 'Low': 10995.40039, 'Close': 11019.2002, 'Adj Close': 11019.2002, 'Volume': 0.0, 'CloseUSD': 1432.496026}
# 12
# {'Index': 'HSI', 'Date': '1990-09-21', 'Open': 2979.0, 'High': 2979.0, 'Low': 2921.0, 'Close': 2931.0, 'Adj Close': 2931.0, 'Volume': 0.0, 'CloseUSD': 381.03}
# 13
# {'Index': 'N100', 'Date': '2020-03-27', 'Open': 860.659973, 'High': 866.5, 'Low': 832.799988, 'Close': 843.390015, 'Adj Close': 843.390015, 'Volume': 407858300.0, 'CloseUSD': 1028.9358183}
# 14
# {'Index': 'J203.JO', 'Date': '2016-02-12', 'Open': 47411.57031, 'High': 48838.01953, 'Low': 47411.57031, 'Close': 48589.69141, 'Adj Close': 48589.69141, 'Volume': 0.0, 'CloseUSD': 3401.2783987000003}
# 15
# {'Index': 'IXIC', 'Date': '2005-10-12', 'Open': 2055.439941, 'High': 2064.659912, 'Low': 2032.790039, 'Close': 2037.469971, 'Adj Close': 2037.469971, 'Volume': 2014750000.0, 'CloseUSD': 2037.469971}
# 16
# {'Index': 'NYA', 'Date': '2006-10-31', 'Open': 8766.780273, 'High': 8786.849609, 'Low': 8740.209961, 'Close': 8774.980469, 'Adj Close': 8774.980469, 'Volume': 2803030000.0, 'CloseUSD': 8774.980469}
# 17
# {'Index': 'NYA', 'Date': '2019-12-31', 'Open': 13852.59961, 'High': 13915.74023, 'Low': 13843.98047, 'Close': 13913.03027, 'Adj Close': 13913.03027, 'Volume': 2893810000.0, 'CloseUSD': 13913.03027}
# 18
# {'Index': 'TWII', 'Date': '2010-09-27', 'Open': 8239.110352, 'High': 8240.860352, 'Low': 8189.379883, 'Close': 8191.540039, 'Adj Close': 8191.509277, 'Volume': 4624400.0, 'CloseUSD': 327.66160156}
# 19
# {'Index': 'IXIC', 'Date': '2020-11-09', 'Open': 12046.66016, 'High': 12108.07031, 'Low': 11703.49023, 'Close': 11713.78027, 'Adj Close': 11713.78027, 'Volume': 5823620000.0, 'CloseUSD': 11713.78027}
# 20
# {'Index': 'HSI', 'Date': '2008-10-21', 'Open': 15616.95996, 'High': 15616.95996, 'Low': 14884.07031, 'Close': 15041.16992, 'Adj Close': 15041.16992, 'Volume': 2354328800.0, 'CloseUSD': 1955.3520896}
# 21
# {'Index': '000001.SS', 'Date': '2013-11-14', 'Open': 2087.118896, 'High': 2102.379883, 'Low': 2078.988037, 'Close': 2100.506104, 'Adj Close': 2100.506104, 'Volume': 83800.0, 'CloseUSD': 336.08097664}
# 22
# {'Index': 'NYA', 'Date': '2014-07-24', 'Open': 11038.88965, 'High': 11058.95996, 'Low': 11027.46973, 'Close': 11038.55957, 'Adj Close': 11038.55957, 'Volume': 3203530000.0, 'CloseUSD': 11038.55957}
# 23
# {'Index': 'SSMI', 'Date': '2005-04-21', 'Open': 5889.299805, 'High': 5927.5, 'Low': 5887.600098, 'Close': 5903.0, 'Adj Close': 5903.0, 'Volume': 74916400.0, 'CloseUSD': 6552.330000000001}
# 24
# {'Index': 'NYA', 'Date': '1997-01-07', 'Open': 4196.709961, 'High': 4196.709961, 'Low': 4196.709961, 'Close': 4196.709961, 'Adj Close': 4196.709961, 'Volume': 0.0, 'CloseUSD': 4196.709961}
# 25
# {'Index': 'GSPTSE', 'Date': '1985-02-15', 'Open': 2621.699951, 'High': 2624.399902, 'Low': 2611.800049, 'Close': 2614.399902, 'Adj Close': 2607.760986, 'Volume': 10140000.0, 'CloseUSD': 2169.95191866}
# 26
# {'Index': 'IXIC', 'Date': '2009-09-25', 'Open': 2095.840088, 'High': 2106.98999, 'Low': 2085.350098, 'Close': 2090.919922, 'Adj Close': 2090.919922, 'Volume': 2363930000.0, 'CloseUSD': 2090.919922}
# 27
# {'Index': 'GSPTSE', 'Date': '1980-10-24', 'Open': 2317.0, 'High': 2319.5, 'Low': 2310.199951, 'Close': 2319.199951, 'Adj Close': 2313.310303, 'Volume': 0.0, 'CloseUSD': 1924.93595933}
# 28
# {'Index': 'N225', 'Date': '1992-02-10', 'Open': 22054.10938, 'High': 22054.10938, 'Low': 21819.51953, 'Close': 21819.51953, 'Adj Close': 21819.51953, 'Volume': 0.0, 'CloseUSD': 218.1951953}
# 29
# {'Index': 'N225', 'Date': '1994-06-29', 'Open': 20599.11914, 'High': 20599.11914, 'Low': 20420.48047, 'Close': 20481.0, 'Adj Close': 20481.0, 'Volume': 0.0, 'CloseUSD': 204.81}
# 30
# {'Index': 'NSEI', 'Date': '2020-01-16', 'Open': 12347.09961, 'High': 12389.04981, 'Low': 12315.79981, 'Close': 12355.5, 'Adj Close': 12355.5, 'Volume': 395700.0, 'CloseUSD': 123.555}
# 31
# {'Index': 'HSI', 'Date': '1995-09-29', 'Open': 9602.0, 'High': 9646.299805, 'Low': 9550.400391, 'Close': 9646.299805, 'Adj Close': 9646.299805, 'Volume': 0.0, 'CloseUSD': 1254.01897465}
# 32
# {'Index': '000001.SS', 'Date': '2007-09-05', 'Open': 5296.069824, 'High': 5337.929199, 'Low': 5223.669922, 'Close': 5310.71582, 'Adj Close': 5310.71582, 'Volume': 96200.0, 'CloseUSD': 849.7145312000001}
# 33
# {'Index': 'SSMI', 'Date': '1998-04-14', 'Open': 7624.700195, 'High': 7750.5, 'Low': 7624.700195, 'Close': 7662.899902, 'Adj Close': 7662.899902, 'Volume': 0.0, 'CloseUSD': 8505.81889122}
# 34
# {'Index': 'NYA', 'Date': '1990-04-02', 'Open': 1967.560059, 'High': 1967.560059, 'Low': 1967.560059, 'Close': 1967.560059, 'Adj Close': 1967.560059, 'Volume': 0.0, 'CloseUSD': 1967.560059}
# 35
# {'Index': 'GDAXI', 'Date': '2008-09-15', 'Open': 6138.419922, 'High': 6138.419922, 'Low': 5942.140137, 'Close': 6064.160156, 'Adj Close': 6064.160156, 'Volume': 325805100.0, 'CloseUSD': 7398.27539032}
# 36
# {'Index': '399001.SZ', 'Date': '2021-04-02', 'Open': 14042.12988, 'High': 14178.09961, 'Low': 14008.84961, 'Close': 14122.61035, 'Adj Close': 14122.61035, 'Volume': 1227400.0, 'CloseUSD': 2259.6176560000004}
# 37
# {'Index': 'N225', 'Date': '1991-12-20', 'Open': 22009.41016, 'High': 22200.96094, 'Low': 21768.00977, 'Close': 21777.11914, 'Adj Close': 21777.11914, 'Volume': 0.0, 'CloseUSD': 217.7711914}
# 38
# {'Index': 'NYA', 'Date': '2001-07-24', 'Open': 6324.359863, 'High': 6324.359863, 'Low': 6324.359863, 'Close': 6324.359863, 'Adj Close': 6324.359863, 'Volume': 1198700000.0, 'CloseUSD': 6324.359863}
# 39
# {'Index': 'SSMI', 'Date': '2015-02-09', 'Open': 8535.620117, 'High': 8638.379883, 'Low': 8521.120117, 'Close': 8632.139648, 'Adj Close': 8632.139648, 'Volume': 58406700.0, 'CloseUSD': 9581.67500928}
# 40
# {'Index': 'NSEI', 'Date': '2010-02-11', 'Open': 4757.25, 'High': 4843.799805, 'Low': 4757.25, 'Close': 4826.850098, 'Adj Close': 4826.850098, 'Volume': 0.0, 'CloseUSD': 48.26850098}
# 41
# {'Index': 'NYA', 'Date': '1989-09-08', 'Open': 2050.780029, 'High': 2050.780029, 'Low': 2050.780029, 'Close': 2050.780029, 'Adj Close': 2050.780029, 'Volume': 0.0, 'CloseUSD': 2050.780029}
# 42
# {'Index': 'N225', 'Date': '1999-07-22', 'Open': 18221.07031, 'High': 18221.07031, 'Low': 17665.03906, 'Close': 17730.33984, 'Adj Close': 17730.33984, 'Volume': 0.0, 'CloseUSD': 177.30339840000002}
# 43
# {'Index': 'NSEI', 'Date': '2011-08-18', 'Open': 5077.950195, 'High': 5078.600098, 'Low': 4932.149902, 'Close': 4944.149902, 'Adj Close': 4944.149902, 'Volume': 0.0, 'CloseUSD': 49.44149902}
# 44
# {'Index': 'HSI', 'Date': '2021-03-10', 'Open': 29255.36914, 'High': 29255.36914, 'Low': 28710.91016, 'Close': 28907.51953, 'Adj Close': 28907.51953, 'Volume': 2842785200.0, 'CloseUSD': 3757.9775389}
# 45
# {'Index': 'NYA', 'Date': '1973-11-01', 'Open': 612.640015, 'High': 612.640015, 'Low': 612.640015, 'Close': 612.640015, 'Adj Close': 612.640015, 'Volume': 0.0, 'CloseUSD': 612.640015}
# 46
# {'Index': '000001.SS', 'Date': '2008-12-30', 'Open': 1851.909058, 'High': 1862.937012, 'Low': 1826.97998, 'Close': 1832.910034, 'Adj Close': 1832.910034, 'Volume': 56400.0, 'CloseUSD': 293.26560544}
# 47
# {'Index': 'GSPTSE', 'Date': '1983-03-15', 'Open': 2153.0, 'High': 2153.0, 'Low': 2144.699951, 'Close': 2148.399902, 'Adj Close': 2142.944092, 'Volume': 0.0, 'CloseUSD': 1783.17191866}
# 48
# {'Index': 'N100', 'Date': '2012-08-29', 'Open': 652.929993, 'High': 653.590027, 'Low': 649.469971, 'Close': 651.780029, 'Adj Close': 651.780029, 'Volume': 163883000.0, 'CloseUSD': 795.17163538}
# 49
# {'Index': '399001.SZ', 'Date': '2017-04-20', 'Open': 10346.99023, 'High': 10411.75, 'Low': 10306.38965, 'Close': 10359.08984, 'Adj Close': 10358.97363, 'Volume': 845500.0, 'CloseUSD': 1657.4543744000002}
# 50
# {'Index': 'N225', 'Date': '1982-11-17', 'Open': 7740.100098, 'High': 7740.100098, 'Low': 7740.100098, 'Close': 7740.100098, 'Adj Close': 7740.100098, 'Volume': 0.0, 'CloseUSD': 77.40100098}
# 51
# {'Index': 'GDAXI', 'Date': '1995-12-13', 'Open': 2284.100098, 'High': 2285.97998, 'Low': 2274.129883, 'Close': 2283.26001, 'Adj Close': 2283.26001, 'Volume': 0.0, 'CloseUSD': 2785.5772122}
# 52
# {'Index': 'TWII', 'Date': '2004-11-16', 'Open': 5917.419922, 'High': 5937.620117, 'Low': 5894.97998, 'Close': 5910.850098, 'Adj Close': 5910.828125, 'Volume': 2528200.0, 'CloseUSD': 236.43400392}
# 53
# {'Index': 'HSI', 'Date': '1999-01-05', 'Open': 9800.669922, 'High': 9939.969727, 'Low': 9790.0, 'Close': 9891.05957, 'Adj Close': 9891.05957, 'Volume': 0.0, 'CloseUSD': 1285.8377441}
# 54
# {'Index': 'N225', 'Date': '1968-01-23', 'Open': 1307.550049, 'High': 1307.550049, 'Low': 1307.550049, 'Close': 1307.550049, 'Adj Close': 1307.550049, 'Volume': 0.0, 'CloseUSD': 13.07550049}
# 55
# {'Index': 'N225', 'Date': '1978-12-20', 'Open': 5974.669922, 'High': 5974.669922, 'Low': 5974.669922, 'Close': 5974.669922, 'Adj Close': 5974.669922, 'Volume': 0.0, 'CloseUSD': 59.74669922}
# 56
# {'Index': '399001.SZ', 'Date': '2015-02-25', 'Open': 11755.17969, 'High': 11755.17969, 'Low': 11500.69043, 'Close': 11539.7002, 'Adj Close': 11539.57129, 'Volume': 204300.0, 'CloseUSD': 1846.352032}
# 57
# {'Index': 'SSMI', 'Date': '2018-07-16', 'Open': 8848.219727, 'High': 8872.179688, 'Low': 8816.549805, 'Close': 8847.959961, 'Adj Close': 8847.959961, 'Volume': 41568900.0, 'CloseUSD': 9821.235556710002}
# 58
# {'Index': 'GDAXI', 'Date': '2006-01-20', 'Open': 5433.689941, 'High': 5447.370117, 'Low': 5344.52002, 'Close': 5349.02002, 'Adj Close': 5349.02002, 'Volume': 153096700.0, 'CloseUSD': 6525.804424399999}
# 59
# {'Index': 'GSPTSE', 'Date': '2005-04-27', 'Open': 9392.599609, 'High': 9427.700195, 'Low': 9321.599609, 'Close': 9323.5, 'Adj Close': 9323.5, 'Volume': 11694620000.0, 'CloseUSD': 7738.504999999999}
# 60
# {'Index': 'IXIC', 'Date': '2009-02-12', 'Open': 1510.170044, 'High': 1542.51001, 'Low': 1495.339966, 'Close': 1541.709961, 'Adj Close': 1541.709961, 'Volume': 2428250000.0, 'CloseUSD': 1541.709961}
# 61
# {'Index': '399001.SZ', 'Date': '2005-07-15', 'Open': 2738.48999, 'High': 2754.280029, 'Low': 2706.540039, 'Close': 2716.669922, 'Adj Close': 2716.639404, 'Volume': 15400.0, 'CloseUSD': 434.66718752}
# 62
# {'Index': 'SSMI', 'Date': '2010-10-11', 'Open': 6387.100098, 'High': 6390.879883, 'Low': 6362.089844, 'Close': 6386.180176, 'Adj Close': 6386.180176, 'Volume': 33668500.0, 'CloseUSD': 7088.659995360001}
# 63
# {'Index': 'NYA', 'Date': '1996-04-17', 'Open': 3643.280029, 'High': 3643.280029, 'Low': 3643.280029, 'Close': 3643.280029, 'Adj Close': 3643.280029, 'Volume': 0.0, 'CloseUSD': 3643.280029}
# 64
# {'Index': 'HSI', 'Date': '2005-01-24', 'Open': 13449.87988, 'High': 13483.12988, 'Low': 13320.53027, 'Close': 13386.99023, 'Adj Close': 13386.99023, 'Volume': 450783600.0, 'CloseUSD': 1740.3087299}
# 65
# {'Index': 'TWII', 'Date': '2004-01-09', 'Open': 6241.359863, 'High': 6257.890137, 'Low': 6207.689941, 'Close': 6226.97998, 'Adj Close': 6226.956543, 'Volume': 6117800.0, 'CloseUSD': 249.0791992}
# 66
# {'Index': 'GDAXI', 'Date': '2019-03-22', 'Open': 11578.38965, 'High': 11623.96973, 'Low': 11356.49023, 'Close': 11364.16992, 'Adj Close': 11364.16992, 'Volume': 112187500.0, 'CloseUSD': 13864.2873024}
# 67
# {'Index': 'NYA', 'Date': '1994-02-16', 'Open': 2776.129883, 'High': 2776.129883, 'Low': 2776.129883, 'Close': 2776.129883, 'Adj Close': 2776.129883, 'Volume': 0.0, 'CloseUSD': 2776.129883}
# 68
# {'Index': 'IXIC', 'Date': '1984-11-12', 'Open': 249.199997, 'High': 249.300003, 'Low': 248.800003, 'Close': 249.300003, 'Adj Close': 249.300003, 'Volume': 51230000.0, 'CloseUSD': 249.300003}
# 69
# {'Index': '399001.SZ', 'Date': '2010-08-05', 'Open': 10862.04981, 'High': 10876.66992, 'Low': 10701.67969, 'Close': 10768.08008, 'Adj Close': 10767.95996, 'Volume': 85500.0, 'CloseUSD': 1722.8928128}
# 70
# {'Index': 'GDAXI', 'Date': '1997-04-02', 'Open': 3307.030029, 'High': 3316.310059, 'Low': 3203.340088, 'Close': 3210.939941, 'Adj Close': 3210.939941, 'Volume': 0.0, 'CloseUSD': 3917.34672802}
# 71
# {'Index': 'HSI', 'Date': '2015-11-25', 'Open': 22533.5293, 'High': 22617.21094, 'Low': 22436.00977, 'Close': 22498.0, 'Adj Close': 22498.0, 'Volume': 1513214100.0, 'CloseUSD': 2924.74}
# 72
# {'Index': 'GSPTSE', 'Date': '2018-07-04', 'Open': 16272.40039, 'High': 16330.7002, 'Low': 16260.29981, 'Close': 16304.7002, 'Adj Close': 16304.7002, 'Volume': 6309840000.0, 'CloseUSD': 13532.901166}
# 73
# {'Index': 'GSPTSE', 'Date': '1985-08-06', 'Open': 2788.699951, 'High': 2788.699951, 'Low': 2760.899902, 'Close': 2761.5, 'Adj Close': 2754.487305, 'Volume': 11030000.0, 'CloseUSD': 2292.045}
# 74
# {'Index': 'IXIC', 'Date': '1973-12-20', 'Open': 90.269997, 'High': 90.269997, 'Low': 90.269997, 'Close': 90.269997, 'Adj Close': 90.269997, 'Volume': 0.0, 'CloseUSD': 90.269997}
# 75
# {'Index': 'TWII', 'Date': '2000-09-25', 'Open': 6618.160156, 'High': 6726.75, 'Low': 6550.209961, 'Close': 6677.459961, 'Adj Close': 6677.43457, 'Volume': 0.0, 'CloseUSD': 267.09839844}
# 76
# {'Index': 'IXIC', 'Date': '2020-08-06', 'Open': 10989.98047, 'High': 11121.19043, 'Low': 10963.41016, 'Close': 11108.07031, 'Adj Close': 11108.07031, 'Volume': 4086290000.0, 'CloseUSD': 11108.07031}
# 77
# {'Index': '399001.SZ', 'Date': '1997-10-27', 'Open': 4697.259766, 'High': 4755.259766, 'Low': 4646.850098, 'Close': 4679.759766, 'Adj Close': 4679.707031, 'Volume': 0.0, 'CloseUSD': 748.76156256}
# 78
# {'Index': 'GSPTSE', 'Date': '1992-08-19', 'Open': 3381.199951, 'High': 3391.0, 'Low': 3381.199951, 'Close': 3385.5, 'Adj Close': 3385.5, 'Volume': 25990000.0, 'CloseUSD': 2809.9649999999997}
# 79
# {'Index': 'GSPTSE', 'Date': '2016-12-28', 'Open': 15375.09961, 'High': 15411.90039, 'Low': 15341.2002, 'Close': 15361.09961, 'Adj Close': 15361.09961, 'Volume': 15018880000.0, 'CloseUSD': 12749.7126763}
# 80
# {'Index': 'TWII', 'Date': '2005-09-30', 'Open': 6053.589844, 'High': 6118.609863, 'Low': 6047.200195, 'Close': 6118.609863, 'Adj Close': 6118.587402, 'Volume': 3646800.0, 'CloseUSD': 244.74439452}
# 81
# {'Index': 'HSI', 'Date': '2014-12-29', 'Open': 23694.5293, 'High': 23867.46094, 'Low': 23694.5293, 'Close': 23773.17969, 'Adj Close': 23773.17969, 'Volume': 2133261100.0, 'CloseUSD': 3090.5133597000004}
# 82
# {'Index': 'TWII', 'Date': '2020-04-14', 'Open': 10130.65039, 'High': 10344.12988, 'Low': 10130.65039, 'Close': 10332.94043, 'Adj Close': 10332.94043, 'Volume': 2847000.0, 'CloseUSD': 413.3176172}
# 83
# {'Index': 'NYA', 'Date': '2010-10-22', 'Open': 7515.680176, 'High': 7540.359863, 'Low': 7502.810059, 'Close': 7522.910156, 'Adj Close': 7522.910156, 'Volume': 3177890000.0, 'CloseUSD': 7522.910156}
# 84
# {'Index': 'N225', 'Date': '1965-09-06', 'Open': 1235.780029, 'High': 1235.780029, 'Low': 1235.780029, 'Close': 1235.780029, 'Adj Close': 1235.780029, 'Volume': 0.0, 'CloseUSD': 12.35780029}
# 85
# {'Index': 'J203.JO', 'Date': '2015-02-27', 'Open': 53331.16016, 'High': 53381.21094, 'Low': 53092.30078, 'Close': 53344.19922, 'Adj Close': 53344.19922, 'Volume': 0.0, 'CloseUSD': 3734.0939454}
# 86
# {'Index': '399001.SZ', 'Date': '2011-07-13', 'Open': 12285.87988, 'High': 12491.37988, 'Low': 12285.87988, 'Close': 12479.15039, 'Adj Close': 12479.01074, 'Volume': 75500.0, 'CloseUSD': 1996.6640624}
# 87
# {'Index': 'GSPTSE', 'Date': '1982-10-05', 'Open': 1576.300049, 'High': 1585.699951, 'Low': 1576.300049, 'Close': 1583.099976, 'Adj Close': 1579.079712, 'Volume': 0.0, 'CloseUSD': 1313.9729800799998}
# 88
# {'Index': 'GSPTSE', 'Date': '1985-10-22', 'Open': 2644.399902, 'High': 2652.199951, 'Low': 2644.0, 'Close': 2648.199951, 'Adj Close': 2641.474854, 'Volume': 12710000.0, 'CloseUSD': 2198.00595933}
# 89
# {'Index': 'N225', 'Date': '1996-05-23', 'Open': 21934.08008, 'High': 22014.86914, 'Low': 21631.83008, 'Close': 21724.08008, 'Adj Close': 21724.08008, 'Volume': 0.0, 'CloseUSD': 217.2408008}
# 90
# {'Index': 'N225', 'Date': '1969-05-30', 'Open': 1990.530029, 'High': 1990.530029, 'Low': 1990.530029, 'Close': 1990.530029, 'Adj Close': 1990.530029, 'Volume': 0.0, 'CloseUSD': 19.90530029}
# 91
# {'Index': 'NSEI', 'Date': '2017-03-22', 'Open': 9047.200195, 'High': 9072.900391, 'Low': 9019.299805, 'Close': 9030.450195, 'Adj Close': 9030.450195, 'Volume': 232300.0, 'CloseUSD': 90.30450195}
# 92
# {'Index': 'NYA', 'Date': '1996-09-09', 'Open': 3767.209961, 'High': 3767.209961, 'Low': 3767.209961, 'Close': 3767.209961, 'Adj Close': 3767.209961, 'Volume': 0.0, 'CloseUSD': 3767.209961}
# 93
# {'Index': 'GSPTSE', 'Date': '1984-01-05', 'Open': 2563.0, 'High': 2582.100098, 'Low': 2563.0, 'Close': 2578.0, 'Adj Close': 2571.453369, 'Volume': 0.0, 'CloseUSD': 2139.74}
# 94
# {'Index': 'GSPTSE', 'Date': '2015-01-06', 'Open': 14368.09961, 'High': 14370.40039, 'Low': 14162.0, 'Close': 14246.79981, 'Adj Close': 14246.79981, 'Volume': 27337450000.0, 'CloseUSD': 11824.8438423}
# 95
# {'Index': 'HSI', 'Date': '2006-10-20', 'Open': 18012.60938, 'High': 18148.03906, 'Low': 18012.60938, 'Close': 18113.55078, 'Adj Close': 18113.55078, 'Volume': 815419100.0, 'CloseUSD': 2354.7616014000005}
# 96
# {'Index': 'TWII', 'Date': '2008-12-23', 'Open': 4517.049805, 'High': 4523.129883, 'Low': 4359.549805, 'Close': 4405.859863, 'Adj Close': 4405.84375, 'Volume': 3253400.0, 'CloseUSD': 176.23439452}
# 97
# {'Index': 'TWII', 'Date': '1997-07-02', 'Open': 9094.269531, 'High': 9124.299805, 'Low': 8988.129883, 'Close': 8996.719727, 'Adj Close': 8996.686523, 'Volume': 0.0, 'CloseUSD': 359.86878908}
# 98
# {'Index': 'N225', 'Date': '2002-10-16', 'Open': 8934.070313, 'High': 8974.790039, 'Low': 8826.419922, 'Close': 8884.870117, 'Adj Close': 8884.870117, 'Volume': 48600000.0, 'CloseUSD': 88.84870117000001}
# 99
# {'Index': 'N225', 'Date': '2020-03-19', 'Open': 16995.76953, 'High': 17160.9707, 'Low': 16358.19043, 'Close': 16552.83008, 'Adj Close': 16552.83008, 'Volume': 198900000.0, 'CloseUSD': 165.5283008}
# 100
# {'Index': 'N100', 'Date': '2003-08-04', 'Open': 546.340027, 'High': 554.539978, 'Low': 542.76001, 'Close': 544.340027, 'Adj Close': 544.340027, 'Volume': 0.0, 'CloseUSD': 664.09483294}
# 101
# {'Index': 'NYA', 'Date': '1986-12-31', 'Open': 1465.310059, 'High': 1465.310059, 'Low': 1465.310059, 'Close': 1465.310059, 'Adj Close': 1465.310059, 'Volume': 0.0, 'CloseUSD': 1465.310059}
# 102
# {'Index': 'N225', 'Date': '2012-01-16', 'Open': 8409.790039, 'High': 8409.790039, 'Low': 8352.230469, 'Close': 8378.360352, 'Adj Close': 8378.360352, 'Volume': 76500000.0, 'CloseUSD': 83.78360352}
# 103
# {'Index': 'J203.JO', 'Date': '2012-08-23', 'Open': 35616.71094, 'High': 35865.10938, 'Low': 35616.71094, 'Close': 35843.92188, 'Adj Close': 35843.92188, 'Volume': 0.0, 'CloseUSD': 2509.0745316}
# 104
# {'Index': 'NYA', 'Date': '1994-11-10', 'Open': 2689.429932, 'High': 2689.429932, 'Low': 2689.429932, 'Close': 2689.429932, 'Adj Close': 2689.429932, 'Volume': 0.0, 'CloseUSD': 2689.429932}
# 105
# {'Index': 'N225', 'Date': '1989-02-14', 'Open': 31977.34961, 'High': 32076.7793, 'Low': 31936.33984, 'Close': 31982.89063, 'Adj Close': 31982.89063, 'Volume': 0.0, 'CloseUSD': 319.8289063}
# 106
# {'Index': '399001.SZ', 'Date': '2011-04-18', 'Open': 12912.98047, 'High': 13045.82031, 'Low': 12881.58984, 'Close': 13001.33008, 'Adj Close': 13001.18457, 'Volume': 141200.0, 'CloseUSD': 2080.2128128}
# 107
# {'Index': 'J203.JO', 'Date': '2013-09-23', 'Open': 44094.30859, 'High': 44133.37109, 'Low': 43944.91016, 'Close': 44017.73047, 'Adj Close': 44017.73047, 'Volume': 0.0, 'CloseUSD': 3081.2411329000006}
# 108
# {'Index': 'NYA', 'Date': '1966-12-12', 'Open': 475.079987, 'High': 475.079987, 'Low': 475.079987, 'Close': 475.079987, 'Adj Close': 475.079987, 'Volume': 0.0, 'CloseUSD': 475.079987}
# 109
# {'Index': 'N225', 'Date': '2018-07-27', 'Open': 22646.48047, 'High': 22712.75, 'Low': 22593.19922, 'Close': 22712.75, 'Adj Close': 22712.75, 'Volume': 73200000.0, 'CloseUSD': 227.1275}
# 110
# {'Index': 'GSPTSE', 'Date': '1993-02-08', 'Open': 3388.300049, 'High': 3401.0, 'Low': 3384.0, 'Close': 3394.800049, 'Adj Close': 3394.800049, 'Volume': 49500000.0, 'CloseUSD': 2817.68404067}
# 111
# {'Index': 'GDAXI', 'Date': '2009-02-03', 'Open': 4302.52002, 'High': 4385.439941, 'Low': 4224.529785, 'Close': 4374.959961, 'Adj Close': 4374.959961, 'Volume': 130716600.0, 'CloseUSD': 5337.45115242}
# 112
# {'Index': 'IXIC', 'Date': '1983-05-09', 'Open': 302.649994, 'High': 302.649994, 'Low': 302.649994, 'Close': 302.649994, 'Adj Close': 302.649994, 'Volume': 0.0, 'CloseUSD': 302.649994}
# 113
# {'Index': 'TWII', 'Date': '2004-11-12', 'Open': 5901.790039, 'High': 5952.450195, 'Low': 5894.390137, 'Close': 5917.160156, 'Adj Close': 5917.138184, 'Volume': 3198400.0, 'CloseUSD': 236.68640624}
# 114
# {'Index': 'N225', 'Date': '2015-03-17', 'Open': 19425.89063, 'High': 19479.89063, 'Low': 19373.39063, 'Close': 19437.0, 'Adj Close': 19437.0, 'Volume': 131800000.0, 'CloseUSD': 194.37}
# 115
# {'Index': 'IXIC', 'Date': '1978-08-16', 'Open': 132.770004, 'High': 132.770004, 'Low': 132.770004, 'Close': 132.770004, 'Adj Close': 132.770004, 'Volume': 0.0, 'CloseUSD': 132.770004}
# 116
# {'Index': 'NYA', 'Date': '1987-12-07', 'Open': 1355.869995, 'High': 1355.869995, 'Low': 1355.869995, 'Close': 1355.869995, 'Adj Close': 1355.869995, 'Volume': 0.0, 'CloseUSD': 1355.869995}
# 117
# {'Index': 'NYA', 'Date': '1977-11-30', 'Open': 553.640015, 'High': 553.640015, 'Low': 553.640015, 'Close': 553.640015, 'Adj Close': 553.640015, 'Volume': 0.0, 'CloseUSD': 553.640015}
# 118
# {'Index': 'N225', 'Date': '2004-09-03', 'Open': 11182.09961, 'High': 11186.82031, 'Low': 11013.36035, 'Close': 11022.49023, 'Adj Close': 11022.49023, 'Volume': 75000000.0, 'CloseUSD': 110.2249023}
# 119
# {'Index': 'IXIC', 'Date': '1995-07-13', 'Open': 989.27002, 'High': 999.590027, 'Low': 988.25, 'Close': 994.150024, 'Adj Close': 994.150024, 'Volume': 530100000.0, 'CloseUSD': 994.150024}
# 120
# {'Index': 'HSI', 'Date': '2008-02-25', 'Open': 23546.09961, 'High': 23552.99023, 'Low': 23164.9707, 'Close': 23269.14063, 'Adj Close': 23269.14063, 'Volume': 1323817100.0, 'CloseUSD': 3024.9882819000004}
# 121
# {'Index': 'GSPTSE', 'Date': '2015-05-26', 'Open': 15181.0, 'High': 15188.7002, 'Low': 14974.29981, 'Close': 15050.79981, 'Adj Close': 15050.79981, 'Volume': 14893260000.0, 'CloseUSD': 12492.1638423}
# 122
# {'Index': 'NYA', 'Date': '2018-11-01', 'Open': 12208.05957, 'High': 12363.32031, 'Low': 12208.05957, 'Close': 12356.5, 'Adj Close': 12356.5, 'Volume': 4708420000.0, 'CloseUSD': 12356.5}
# 123
# {'Index': 'GDAXI', 'Date': '2014-06-19', 'Open': 10018.91016, 'High': 10023.54981, 'Low': 9993.030273, 'Close': 10004.0, 'Adj Close': 10004.0, 'Volume': 86693500.0, 'CloseUSD': 12204.88}
# 124
# {'Index': 'GDAXI', 'Date': '2003-01-10', 'Open': 3037.800049, 'High': 3093.780029, 'Low': 2986.75, 'Close': 3037.330078, 'Adj Close': 3037.330078, 'Volume': 112102800.0, 'CloseUSD': 3705.54269516}
# 125
# {'Index': 'SSMI', 'Date': '1994-06-08', 'Open': 2778.100098, 'High': 2804.800049, 'Low': 2773.399902, 'Close': 2801.100098, 'Adj Close': 2801.100098, 'Volume': 0.0, 'CloseUSD': 3109.22110878}
# 126
# {'Index': 'NSEI', 'Date': '2008-04-22', 'Open': 5037.049805, 'High': 5074.25, 'Low': 4994.049805, 'Close': 5049.299805, 'Adj Close': 5049.299805, 'Volume': 0.0, 'CloseUSD': 50.49299805}
# 127
# {'Index': 'GSPTSE', 'Date': '2003-07-21', 'Open': 7118.5, 'High': 7137.299805, 'Low': 7113.899902, 'Close': 7136.0, 'Adj Close': 7136.0, 'Volume': 10847050000.0, 'CloseUSD': 5922.88}
# 128
# {'Index': 'NYA', 'Date': '1967-09-01', 'Open': 551.419983, 'High': 551.419983, 'Low': 551.419983, 'Close': 551.419983, 'Adj Close': 551.419983, 'Volume': 0.0, 'CloseUSD': 551.419983}
# 129
# {'Index': 'N225', 'Date': '2005-08-15', 'Open': 12254.53027, 'High': 12308.61035, 'Low': 12236.61035, 'Close': 12256.54981, 'Adj Close': 12256.54981, 'Volume': 103600000.0, 'CloseUSD': 122.5654981}
# 130
# {'Index': 'TWII', 'Date': '2002-03-18', 'Open': 5999.600098, 'High': 6002.330078, 'Low': 5917.069824, 'Close': 5972.109863, 'Adj Close': 5972.087891, 'Volume': 0.0, 'CloseUSD': 238.88439452}
# 131
# {'Index': '399001.SZ', 'Date': '2004-01-09', 'Open': 3767.179932, 'High': 3804.300049, 'Low': 3693.050049, 'Close': 3696.419922, 'Adj Close': 3696.378418, 'Volume': 0.0, 'CloseUSD': 591.4271875200001}
# 132
# {'Index': 'IXIC', 'Date': '2008-01-15', 'Open': 2449.040039, 'High': 2455.290039, 'Low': 2412.469971, 'Close': 2417.590088, 'Adj Close': 2417.590088, 'Volume': 2390120000.0, 'CloseUSD': 2417.590088}
# 133
# {'Index': 'IXIC', 'Date': '1992-09-23', 'Open': 581.929993, 'High': 583.429993, 'Low': 580.340027, 'Close': 582.960022, 'Adj Close': 582.960022, 'Volume': 193240000.0, 'CloseUSD': 582.960022}
# 134
# {'Index': 'IXIC', 'Date': '2001-03-22', 'Open': 1845.339966, 'High': 1898.099976, 'Low': 1794.209961, 'Close': 1897.699951, 'Adj Close': 1897.699951, 'Volume': 2504770000.0, 'CloseUSD': 1897.699951}
# 135
# {'Index': 'NSEI', 'Date': '2016-05-18', 'Open': 7846.75, 'High': 7882.049805, 'Low': 7810.75, 'Close': 7870.149902, 'Adj Close': 7870.149902, 'Volume': 156400.0, 'CloseUSD': 78.70149902}
# 136
# {'Index': 'IXIC', 'Date': '1982-01-29', 'Open': 188.389999, 'High': 188.389999, 'Low': 188.389999, 'Close': 188.389999, 'Adj Close': 188.389999, 'Volume': 0.0, 'CloseUSD': 188.389999}
# 137
# {'Index': 'N100', 'Date': '2005-11-21', 'Open': 781.76001, 'High': 785.599976, 'Low': 780.130005, 'Close': 784.51001, 'Adj Close': 784.51001, 'Volume': 0.0, 'CloseUSD': 957.1022122}
# 138
# {'Index': 'IXIC', 'Date': '1997-04-03', 'Open': 1199.119995, 'High': 1213.77002, 'Low': 1196.219971, 'Close': 1213.76001, 'Adj Close': 1213.76001, 'Volume': 580490000.0, 'CloseUSD': 1213.76001}
# 139
# {'Index': 'N225', 'Date': '2003-07-28', 'Open': 9750.200195, 'High': 9846.19043, 'Low': 9737.150391, 'Close': 9839.910156, 'Adj Close': 9839.910156, 'Volume': 67500000.0, 'CloseUSD': 98.39910156}
# 140
# {'Index': 'J203.JO', 'Date': '2013-07-05', 'Open': 40030.19141, 'High': 40062.64844, 'Low': 39169.82813, 'Close': 39169.82813, 'Adj Close': 39169.82813, 'Volume': 0.0, 'CloseUSD': 2741.8879691}
# 141
# {'Index': 'HSI', 'Date': '2010-01-22', 'Open': 20527.19922, 'High': 20738.99023, 'Low': 20250.35938, 'Close': 20726.17969, 'Adj Close': 20726.17969, 'Volume': 3220362000.0, 'CloseUSD': 2694.4033597}
# 142
# {'Index': 'NYA', 'Date': '1985-01-11', 'Open': 1025.439941, 'High': 1025.439941, 'Low': 1025.439941, 'Close': 1025.439941, 'Adj Close': 1025.439941, 'Volume': 0.0, 'CloseUSD': 1025.439941}
# 143
# {'Index': 'N225', 'Date': '2003-01-29', 'Open': 8529.669922, 'High': 8529.669922, 'Low': 8304.049805, 'Close': 8331.080078, 'Adj Close': 8331.080078, 'Volume': 54100000.0, 'CloseUSD': 83.31080078000001}
# 144
# {'Index': 'GDAXI', 'Date': '1990-11-16', 'Open': 1430.199951, 'High': 1430.199951, 'Low': 1430.199951, 'Close': 1430.199951, 'Adj Close': 1430.199951, 'Volume': 0.0, 'CloseUSD': 1744.84394022}
# 145
# {'Index': 'IXIC', 'Date': '1993-08-13', 'Open': 717.679993, 'High': 718.280029, 'Low': 716.549988, 'Close': 718.26001, 'Adj Close': 718.26001, 'Volume': 233590000.0, 'CloseUSD': 718.26001}
# 146
# {'Index': '000001.SS', 'Date': '2008-07-16', 'Open': 2753.897949, 'High': 2765.147949, 'Low': 2656.613037, 'Close': 2705.866943, 'Adj Close': 2705.866943, 'Volume': 60000.0, 'CloseUSD': 432.93871088}
# 147
# {'Index': 'N225', 'Date': '1998-07-03', 'Open': 16354.59961, 'High': 16625.41992, 'Low': 16289.66016, 'Close': 16511.24023, 'Adj Close': 16511.24023, 'Volume': 0.0, 'CloseUSD': 165.1124023}
# 148
# {'Index': 'IXIC', 'Date': '1996-07-05', 'Open': 1172.810059, 'High': 1172.810059, 'Low': 1158.339966, 'Close': 1158.349976, 'Adj Close': 1158.349976, 'Volume': 216200000.0, 'CloseUSD': 1158.349976}
# 149
# {'Index': 'NYA', 'Date': '1973-12-12', 'Open': 526.890015, 'High': 526.890015, 'Low': 526.890015, 'Close': 526.890015, 'Adj Close': 526.890015, 'Volume': 0.0, 'CloseUSD': 526.890015}
# 150
# {'Index': 'HSI', 'Date': '2003-04-16', 'Open': 8653.589844, 'High': 8705.269531, 'Low': 8609.459961, 'Close': 8675.139648, 'Adj Close': 8675.139648, 'Volume': 171986800.0, 'CloseUSD': 1127.76815424}
# 151
# {'Index': 'TWII', 'Date': '2015-05-07', 'Open': 9789.820313, 'High': 9789.820313, 'Low': 9704.110352, 'Close': 9704.110352, 'Adj Close': 9704.073242, 'Volume': 2315900.0, 'CloseUSD': 388.16441408}
# 152
# {'Index': 'IXIC', 'Date': '2000-11-16', 'Open': 3121.800049, 'High': 3175.629883, 'Low': 3031.76001, 'Close': 3031.879883, 'Adj Close': 3031.879883, 'Volume': 1523710000.0, 'CloseUSD': 3031.879883}
# 153
# {'Index': 'N100', 'Date': '2018-08-22', 'Open': 1059.800049, 'High': 1066.47998, 'Low': 1059.800049, 'Close': 1063.52002, 'Adj Close': 1063.52002, 'Volume': 167431000.0, 'CloseUSD': 1297.4944243999998}
# 154
# {'Index': 'GSPTSE', 'Date': '2018-02-26', 'Open': 15701.09961, 'High': 15735.2002, 'Low': 15652.2002, 'Close': 15714.7002, 'Adj Close': 15714.7002, 'Volume': 17284450000.0, 'CloseUSD': 13043.201166}
# 155
# {'Index': 'NSEI', 'Date': '2012-03-13', 'Open': 5391.049805, 'High': 5438.649902, 'Low': 5390.799805, 'Close': 5429.5, 'Adj Close': 5429.5, 'Volume': 0.0, 'CloseUSD': 54.295}
# 156
# {'Index': '399001.SZ', 'Date': '2000-05-17', 'Open': 4349.819824, 'High': 4405.450195, 'Low': 4314.189941, 'Close': 4357.089844, 'Adj Close': 4357.041016, 'Volume': 0.0, 'CloseUSD': 697.13437504}
# 157
# {'Index': 'GSPTSE', 'Date': '2004-04-06', 'Open': 8813.0, 'High': 8864.400391, 'Low': 8805.099609, 'Close': 8832.700195, 'Adj Close': 8832.700195, 'Volume': 11195540000.0, 'CloseUSD': 7331.141161849999}
# 158
# {'Index': 'GDAXI', 'Date': '2005-02-07', 'Open': 4342.75, 'High': 4373.899902, 'Low': 4342.75, 'Close': 4366.350098, 'Adj Close': 4366.350098, 'Volume': 90195200.0, 'CloseUSD': 5326.94711956}
# 159
# {'Index': 'IXIC', 'Date': '1992-03-19', 'Open': 627.01001, 'High': 627.349976, 'Low': 625.340027, 'Close': 625.960022, 'Adj Close': 625.960022, 'Volume': 189970000.0, 'CloseUSD': 625.960022}
# 160
# {'Index': 'NSEI', 'Date': '2020-05-21', 'Open': 9079.450195, 'High': 9178.549805, 'Low': 9056.099609, 'Close': 9106.25, 'Adj Close': 9106.25, 'Volume': 631500.0, 'CloseUSD': 91.0625}
# 161
# {'Index': 'N100', 'Date': '2011-05-30', 'Open': 704.789978, 'High': 707.27002, 'Low': 703.380005, 'Close': 704.890015, 'Adj Close': 704.890015, 'Volume': 91617400.0, 'CloseUSD': 859.9658182999999}
# 162
# {'Index': 'TWII', 'Date': '2014-12-15', 'Open': 8987.950195, 'High': 8997.080078, 'Low': 8943.040039, 'Close': 8985.629883, 'Adj Close': 8985.59668, 'Volume': 1671300.0, 'CloseUSD': 359.42519532}
# 163
# {'Index': 'TWII', 'Date': '1999-06-23', 'Open': 8607.540039, 'High': 8661.389648, 'Low': 8486.969727, 'Close': 8492.320313, 'Adj Close': 8492.288086, 'Volume': 0.0, 'CloseUSD': 339.69281252}
# 164
# {'Index': '399001.SZ', 'Date': '2013-09-25', 'Open': 8642.490234, 'High': 8707.5, 'Low': 8587.370117, 'Close': 8613.709961, 'Adj Close': 8613.613281, 'Volume': 150600.0, 'CloseUSD': 1378.19359376}
# 165
# {'Index': 'HSI', 'Date': '1995-11-29', 'Open': 9623.400391, 'High': 9648.799805, 'Low': 9579.700195, 'Close': 9617.299805, 'Adj Close': 9617.299805, 'Volume': 0.0, 'CloseUSD': 1250.24897465}
# 166
# {'Index': 'NYA', 'Date': '2005-02-08', 'Open': 7200.899902, 'High': 7213.779785, 'Low': 7186.799805, 'Close': 7207.450195, 'Adj Close': 7207.450195, 'Volume': 1416170000.0, 'CloseUSD': 7207.450195}
# 167
# {'Index': '399001.SZ', 'Date': '2008-11-17', 'Open': 6634.629883, 'High': 6783.029785, 'Low': 6576.839844, 'Close': 6783.029785, 'Adj Close': 6782.953613, 'Volume': 135800.0, 'CloseUSD': 1085.2847656}
# 168
# {'Index': '399001.SZ', 'Date': '2015-09-08', 'Open': 9898.639648, 'High': 10341.29981, 'Low': 9763.950195, 'Close': 10320.23047, 'Adj Close': 10320.11426, 'Volume': 1067800.0, 'CloseUSD': 1651.2368752000002}
# 169
# {'Index': 'HSI', 'Date': '2008-04-03', 'Open': 23947.55078, 'High': 24334.18945, 'Low': 23937.31055, 'Close': 24264.63086, 'Adj Close': 24264.63086, 'Volume': 2489106000.0, 'CloseUSD': 3154.4020118000003}
# 170
# {'Index': 'GSPTSE', 'Date': '2006-06-30', 'Open': 11609.90039, 'High': 11658.79981, 'Low': 11520.90039, 'Close': 11612.90039, 'Adj Close': 11612.90039, 'Volume': 15267290000.0, 'CloseUSD': 9638.7073237}
# 171
# {'Index': 'GSPTSE', 'Date': '2009-11-20', 'Open': 11524.5, 'High': 11600.29981, 'Low': 11508.79981, 'Close': 11579.29981, 'Adj Close': 11579.29981, 'Volume': 15151580000.0, 'CloseUSD': 9610.8188423}
# 172
# {'Index': '399001.SZ', 'Date': '2000-01-17', 'Open': 3535.51001, 'High': 3597.77002, 'Low': 3496.0, 'Close': 3594.649902, 'Adj Close': 3594.609619, 'Volume': 0.0, 'CloseUSD': 575.1439843200001}
# 173
# {'Index': 'GDAXI', 'Date': '2014-09-03', 'Open': 9541.019531, 'High': 9683.099609, 'Low': 9528.719727, 'Close': 9626.490234, 'Adj Close': 9626.490234, 'Volume': 90121000.0, 'CloseUSD': 11744.31808548}
# 174
# {'Index': 'GSPTSE', 'Date': '2005-10-13', 'Open': 10476.40039, 'High': 10498.79981, 'Low': 10294.90039, 'Close': 10429.7002, 'Adj Close': 10429.7002, 'Volume': 14691450000.0, 'CloseUSD': 8656.651166}
# 175
# {'Index': 'N225', 'Date': '2004-04-09', 'Open': 12012.62988, 'High': 12012.62988, 'Low': 11862.33984, 'Close': 11897.50977, 'Adj Close': 11897.50977, 'Volume': 105400000.0, 'CloseUSD': 118.9750977}
# 176
# {'Index': 'IXIC', 'Date': '1992-04-24', 'Open': 576.409973, 'High': 576.859985, 'Low': 571.98999, 'Close': 572.890015, 'Adj Close': 572.890015, 'Volume': 165970000.0, 'CloseUSD': 572.890015}
# 177
# {'Index': 'NYA', 'Date': '1973-11-12', 'Open': 591.710022, 'High': 591.710022, 'Low': 591.710022, 'Close': 591.710022, 'Adj Close': 591.710022, 'Volume': 0.0, 'CloseUSD': 591.710022}
# 178
# {'Index': 'IXIC', 'Date': '1993-07-14', 'Open': 708.77002, 'High': 713.960022, 'Low': 707.869995, 'Close': 712.48999, 'Adj Close': 712.48999, 'Volume': 290560000.0, 'CloseUSD': 712.48999}
# 179
# {'Index': '000001.SS', 'Date': '2008-07-07', 'Open': 2673.550049, 'High': 2801.533936, 'Low': 2673.550049, 'Close': 2792.396973, 'Adj Close': 2792.396973, 'Volume': 77400.0, 'CloseUSD': 446.78351568}
# 180
# {'Index': 'HSI', 'Date': '1998-06-26', 'Open': 8635.990234, 'High': 8702.25, 'Low': 8410.599609, 'Close': 8607.860352, 'Adj Close': 8607.860352, 'Volume': 0.0, 'CloseUSD': 1119.02184576}
# 181
# {'Index': '399001.SZ', 'Date': '2018-10-18', 'Open': 7309.0, 'High': 7316.189941, 'Low': 7182.390137, 'Close': 7187.490234, 'Adj Close': 7187.461914, 'Volume': 74200.0, 'CloseUSD': 1149.99843744}
# 182
# {'Index': 'N225', 'Date': '2015-09-15', 'Open': 18082.7207, 'High': 18329.57031, 'Low': 17995.98047, 'Close': 18026.48047, 'Adj Close': 18026.48047, 'Volume': 146400000.0, 'CloseUSD': 180.2648047}
# 183
# {'Index': 'GDAXI', 'Date': '2018-04-16', 'Open': 12478.99023, 'High': 12487.04004, 'Low': 12375.62988, 'Close': 12391.41016, 'Adj Close': 12391.41016, 'Volume': 62656800.0, 'CloseUSD': 15117.5203952}
# 184
# {'Index': 'GDAXI', 'Date': '1993-04-01', 'Open': 1670.040039, 'High': 1670.040039, 'Low': 1670.040039, 'Close': 1670.040039, 'Adj Close': 1670.040039, 'Volume': 0.0, 'CloseUSD': 2037.44884758}
# 185
# {'Index': 'N225', 'Date': '2020-01-14', 'Open': 23969.03906, 'High': 24059.85938, 'Low': 23951.66016, 'Close': 24025.16992, 'Adj Close': 24025.16992, 'Volume': 64200000.0, 'CloseUSD': 240.2516992}
# 186
# {'Index': 'NYA', 'Date': '1967-10-13', 'Open': 563.789978, 'High': 563.789978, 'Low': 563.789978, 'Close': 563.789978, 'Adj Close': 563.789978, 'Volume': 0.0, 'CloseUSD': 563.789978}
# 187
# {'Index': '000001.SS', 'Date': '2014-07-29', 'Open': 2179.825928, 'High': 2193.522949, 'Low': 2172.102051, 'Close': 2183.191895, 'Adj Close': 2183.191895, 'Volume': 200300.0, 'CloseUSD': 349.3107032}
# 188
# {'Index': 'IXIC', 'Date': '2008-04-07', 'Open': 2386.620117, 'High': 2390.040039, 'Low': 2359.540039, 'Close': 2364.830078, 'Adj Close': 2364.830078, 'Volume': 1730020000.0, 'CloseUSD': 2364.830078}
# 189
# {'Index': 'N225', 'Date': '1968-12-17', 'Open': 1711.569946, 'High': 1711.569946, 'Low': 1711.569946, 'Close': 1711.569946, 'Adj Close': 1711.569946, 'Volume': 0.0, 'CloseUSD': 17.115699460000002}
# 190
# {'Index': 'IXIC', 'Date': '1979-03-02', 'Open': 123.669998, 'High': 123.669998, 'Low': 123.669998, 'Close': 123.669998, 'Adj Close': 123.669998, 'Volume': 0.0, 'CloseUSD': 123.669998}
# 191
# {'Index': 'NSEI', 'Date': '2020-09-09', 'Open': 11218.59961, 'High': 11298.15039, 'Low': 11185.15039, 'Close': 11278.0, 'Adj Close': 11278.0, 'Volume': 728900.0, 'CloseUSD': 112.78}
# 192
# {'Index': '399001.SZ', 'Date': '2007-06-28', 'Open': 13544.04981, 'High': 13629.4502, 'Low': 12856.25977, 'Close': 12882.16992, 'Adj Close': 12882.02539, 'Volume': 75700.0, 'CloseUSD': 2061.1471872}
# 193
# {'Index': 'GSPTSE', 'Date': '1990-09-17', 'Open': 3245.699951, 'High': 3262.5, 'Low': 3245.699951, 'Close': 3262.0, 'Adj Close': 3253.716064, 'Volume': 20740000.0, 'CloseUSD': 2707.46}
# 194
# {'Index': 'TWII', 'Date': '1999-06-29', 'Open': 8428.839844, 'High': 8514.269531, 'Low': 8407.950195, 'Close': 8514.269531, 'Adj Close': 8514.237305, 'Volume': 0.0, 'CloseUSD': 340.57078124000003}
# 195
# {'Index': 'GDAXI', 'Date': '2000-02-10', 'Open': 7617.069824, 'High': 7709.27002, 'Low': 7496.419922, 'Close': 7709.27002, 'Adj Close': 7709.27002, 'Volume': 56564600.0, 'CloseUSD': 9405.3094244}
# 196
# {'Index': 'NYA', 'Date': '1977-02-23', 'Open': 576.27002, 'High': 576.27002, 'Low': 576.27002, 'Close': 576.27002, 'Adj Close': 576.27002, 'Volume': 0.0, 'CloseUSD': 576.27002}
# 197
# {'Index': '000001.SS', 'Date': '2005-12-22', 'Open': 1129.563965, 'High': 1136.000977, 'Low': 1125.953979, 'Close': 1135.238037, 'Adj Close': 1135.238037, 'Volume': 11200.0, 'CloseUSD': 181.63808592}
# 198
# {'Index': 'TWII', 'Date': '2006-09-08', 'Open': 6664.109863, 'High': 6718.830078, 'Low': 6654.77002, 'Close': 6693.109863, 'Adj Close': 6693.083984, 'Volume': 2326000.0, 'CloseUSD': 267.72439452}
# 199
# {'Index': 'N225', 'Date': '1972-05-18', 'Open': 3438.189941, 'High': 3438.189941, 'Low': 3438.189941, 'Close': 3438.189941, 'Adj Close': 3438.189941, 'Volume': 0.0, 'CloseUSD': 34.38189941}
# 200
# {'Index': 'SSMI', 'Date': '2012-08-17', 'Open': 6553.819824, 'High': 6554.120117, 'Low': 6519.689941, 'Close': 6529.339844, 'Adj Close': 6529.339844, 'Volume': 45997700.0, 'CloseUSD': 7247.56722684}
# 201
# {'Index': 'TWII', 'Date': '2009-03-30', 'Open': 5362.899902, 'High': 5362.899902, 'Low': 5166.870117, 'Close': 5206.049805, 'Adj Close': 5206.030273, 'Volume': 6138600.0, 'CloseUSD': 208.2419922}
# 202
# {'Index': 'N225', 'Date': '1991-12-18', 'Open': 22670.14063, 'High': 22670.14063, 'Low': 22402.32031, 'Close': 22629.90039, 'Adj Close': 22629.90039, 'Volume': 0.0, 'CloseUSD': 226.2990039}
# 203
# {'Index': '399001.SZ', 'Date': '2015-02-10', 'Open': 10887.67969, 'High': 11136.62012, 'Low': 10875.29004, 'Close': 11136.62012, 'Adj Close': 11136.49512, 'Volume': 204700.0, 'CloseUSD': 1781.8592192}
# 204
# {'Index': 'N100', 'Date': '2003-08-05', 'Open': 548.669983, 'High': 553.190002, 'Low': 546.440002, 'Close': 550.950012, 'Adj Close': 550.950012, 'Volume': 0.0, 'CloseUSD': 672.15901464}
# 205
# {'Index': 'GSPTSE', 'Date': '1996-04-29', 'Open': 5143.299805, 'High': 5153.299805, 'Low': 5142.399902, 'Close': 5152.399902, 'Adj Close': 5152.399902, 'Volume': 87820000.0, 'CloseUSD': 4276.49191866}
# 206
# {'Index': 'NYA', 'Date': '1989-07-18', 'Open': 1955.189941, 'High': 1955.189941, 'Low': 1955.189941, 'Close': 1955.189941, 'Adj Close': 1955.189941, 'Volume': 0.0, 'CloseUSD': 1955.189941}
# 207
# {'Index': 'IXIC', 'Date': '2013-03-11', 'Open': 3237.73999, 'High': 3252.870117, 'Low': 3233.669922, 'Close': 3252.870117, 'Adj Close': 3252.870117, 'Volume': 1628500000.0, 'CloseUSD': 3252.870117}
# 208
# {'Index': 'IXIC', 'Date': '2007-05-18', 'Open': 2548.070068, 'High': 2559.030029, 'Low': 2540.669922, 'Close': 2558.449951, 'Adj Close': 2558.449951, 'Volume': 1996930000.0, 'CloseUSD': 2558.449951}
# 209
# {'Index': 'NYA', 'Date': '2006-06-29', 'Open': 7929.709961, 'High': 8138.859863, 'Low': 7929.709961, 'Close': 8138.859863, 'Adj Close': 8138.859863, 'Volume': 2621250000.0, 'CloseUSD': 8138.859863}
# 210
# {'Index': '399001.SZ', 'Date': '2000-10-27', 'Open': 4597.299805, 'High': 4608.259766, 'Low': 4576.629883, 'Close': 4602.569824, 'Adj Close': 4602.518066, 'Volume': 0.0, 'CloseUSD': 736.4111718400001}
# 211
# {'Index': 'GDAXI', 'Date': '1990-01-26', 'Open': 1798.219971, 'High': 1798.219971, 'Low': 1798.219971, 'Close': 1798.219971, 'Adj Close': 1798.219971, 'Volume': 0.0, 'CloseUSD': 2193.82836462}
# 212
# {'Index': 'SSMI', 'Date': '1994-04-12', 'Open': 2884.199951, 'High': 2901.399902, 'Low': 2874.0, 'Close': 2887.800049, 'Adj Close': 2887.800049, 'Volume': 0.0, 'CloseUSD': 3205.45805439}
# 213
# {'Index': 'IXIC', 'Date': '1997-01-27', 'Open': 1367.410034, 'High': 1368.0, 'Low': 1352.180054, 'Close': 1352.810059, 'Adj Close': 1352.810059, 'Volume': 537780000.0, 'CloseUSD': 1352.810059}
# 214
# {'Index': 'NYA', 'Date': '2016-09-16', 'Open': 10554.09961, 'High': 10554.09961, 'Low': 10498.34961, 'Close': 10532.26953, 'Adj Close': 10532.26953, 'Volume': 5014360000.0, 'CloseUSD': 10532.26953}
# 215
# {'Index': 'N100', 'Date': '2020-01-13', 'Open': 1157.930054, 'High': 1160.430054, 'Low': 1152.290039, 'Close': 1155.859985, 'Adj Close': 1155.859985, 'Volume': 157425200.0, 'CloseUSD': 1410.1491817}
# 216
# {'Index': 'NYA', 'Date': '2012-07-17', 'Open': 7763.149902, 'High': 7799.660156, 'Low': 7690.509766, 'Close': 7794.77002, 'Adj Close': 7794.77002, 'Volume': 3566680000.0, 'CloseUSD': 7794.77002}
# 217
# {'Index': 'N100', 'Date': '2000-12-01', 'Open': 1009.0, 'High': 1009.0, 'Low': 1009.0, 'Close': 1009.0, 'Adj Close': 1009.0, 'Volume': 0.0, 'CloseUSD': 1230.98}
# 218
# {'Index': 'N225', 'Date': '1975-08-14', 'Open': 4205.72998, 'High': 4205.72998, 'Low': 4205.72998, 'Close': 4205.72998, 'Adj Close': 4205.72998, 'Volume': 0.0, 'CloseUSD': 42.0572998}
# 219
# {'Index': 'N225', 'Date': '2000-11-16', 'Open': 14852.24023, 'High': 14857.48047, 'Low': 14551.66016, 'Close': 14587.03027, 'Adj Close': 14587.03027, 'Volume': 0.0, 'CloseUSD': 145.8703027}
# 220
# {'Index': 'N100', 'Date': '2011-12-23', 'Open': 582.469971, 'High': 584.72998, 'Low': 581.099976, 'Close': 583.349976, 'Adj Close': 583.349976, 'Volume': 115294800.0, 'CloseUSD': 711.68697072}
# 221
# {'Index': 'NSEI', 'Date': '2021-04-22', 'Open': 14219.15039, 'High': 14424.75, 'Low': 14151.40039, 'Close': 14406.15039, 'Adj Close': 14406.15039, 'Volume': 524600.0, 'CloseUSD': 144.06150390000002}
# 222
# {'Index': 'IXIC', 'Date': '1987-01-28', 'Open': 390.799988, 'High': 392.100006, 'Low': 390.700012, 'Close': 392.0, 'Adj Close': 392.0, 'Volume': 152900000.0, 'CloseUSD': 392.0}
# 223
# {'Index': 'IXIC', 'Date': '1998-07-23', 'Open': 1970.829956, 'High': 1981.050049, 'Low': 1935.219971, 'Close': 1935.219971, 'Adj Close': 1935.219971, 'Volume': 868000000.0, 'CloseUSD': 1935.219971}
# 224
# {'Index': 'N225', 'Date': '2011-09-09', 'Open': 8739.490234, 'High': 8803.75, 'Low': 8726.25, 'Close': 8737.660156, 'Adj Close': 8737.660156, 'Volume': 169300000.0, 'CloseUSD': 87.37660156}
# 225
# {'Index': 'TWII', 'Date': '2000-06-28', 'Open': 8429.049805, 'High': 8476.889648, 'Low': 8248.950195, 'Close': 8365.629883, 'Adj Close': 8365.597656, 'Volume': 0.0, 'CloseUSD': 334.62519532}
# 226
# {'Index': '000001.SS', 'Date': '2016-05-31', 'Open': 2822.593018, 'High': 2917.13501, 'Low': 2822.593018, 'Close': 2916.615967, 'Adj Close': 2916.615967, 'Volume': 215300.0, 'CloseUSD': 466.65855472}
# 227
# {'Index': 'NYA', 'Date': '2006-01-05', 'Open': 7962.939941, 'High': 7965.930176, 'Low': 7928.589844, 'Close': 7944.060059, 'Adj Close': 7944.060059, 'Volume': 2433340000.0, 'CloseUSD': 7944.060059}
# 228
# {'Index': 'N225', 'Date': '1986-12-04', 'Open': 18623.94922, 'High': 18623.94922, 'Low': 18623.94922, 'Close': 18623.94922, 'Adj Close': 18623.94922, 'Volume': 0.0, 'CloseUSD': 186.2394922}
# 229
# {'Index': 'NSEI', 'Date': '2012-02-06', 'Open': 5379.450195, 'High': 5390.049805, 'Low': 5327.25, 'Close': 5361.649902, 'Adj Close': 5361.649902, 'Volume': 0.0, 'CloseUSD': 53.61649902}
# 230
# {'Index': 'IXIC', 'Date': '2004-09-24', 'Open': 1888.890015, 'High': 1897.420044, 'Low': 1879.47998, 'Close': 1879.47998, 'Adj Close': 1879.47998, 'Volume': 1360090000.0, 'CloseUSD': 1879.47998}
# 231
# {'Index': 'NYA', 'Date': '1996-08-13', 'Open': 3728.51001, 'High': 3728.51001, 'Low': 3728.51001, 'Close': 3728.51001, 'Adj Close': 3728.51001, 'Volume': 0.0, 'CloseUSD': 3728.51001}
# 232
# {'Index': 'N225', 'Date': '2007-07-12', 'Open': 18105.89063, 'High': 18130.43945, 'Low': 17919.16992, 'Close': 17984.14063, 'Adj Close': 17984.14063, 'Volume': 125700000.0, 'CloseUSD': 179.84140630000002}
# 233
# {'Index': 'N225', 'Date': '2009-12-30', 'Open': 10707.50977, 'High': 10707.50977, 'Low': 10546.44043, 'Close': 10546.44043, 'Adj Close': 10546.44043, 'Volume': 141500000.0, 'CloseUSD': 105.4644043}
# 234
# {'Index': 'HSI', 'Date': '2000-04-18', 'Open': 15158.15039, 'High': 15409.66992, 'Low': 15158.15039, 'Close': 15278.32031, 'Adj Close': 15278.32031, 'Volume': 0.0, 'CloseUSD': 1986.1816403}
# 235
# {'Index': '399001.SZ', 'Date': '1999-05-24', 'Open': 2781.679932, 'High': 2886.090088, 'Low': 2754.01001, 'Close': 2885.439941, 'Adj Close': 2885.407715, 'Volume': 0.0, 'CloseUSD': 461.67039056}
# 236
# {'Index': '000001.SS', 'Date': '2017-07-19', 'Open': 3181.4021, 'High': 3232.940918, 'Low': 3179.72998, 'Close': 3230.976074, 'Adj Close': 3230.976074, 'Volume': 272400.0, 'CloseUSD': 516.95617184}
# 237
# {'Index': 'GDAXI', 'Date': '2020-01-23', 'Open': 13455.90039, 'High': 13486.13965, 'Low': 13382.23047, 'Close': 13388.41992, 'Adj Close': 13388.41992, 'Volume': 90749900.0, 'CloseUSD': 16333.8723024}
# 238
# {'Index': 'NYA', 'Date': '1986-06-18', 'Open': 1486.97998, 'High': 1486.97998, 'Low': 1486.97998, 'Close': 1486.97998, 'Adj Close': 1486.97998, 'Volume': 0.0, 'CloseUSD': 1486.97998}
# 239
# {'Index': 'TWII', 'Date': '2007-03-02', 'Open': 7653.350098, 'High': 7695.149902, 'Low': 7625.990234, 'Close': 7670.77002, 'Adj Close': 7670.741211, 'Volume': 3742200.0, 'CloseUSD': 306.8308008}
# 240
# {'Index': 'N225', 'Date': '2009-08-05', 'Open': 10405.04981, 'High': 10406.09961, 'Low': 10252.53027, 'Close': 10252.53027, 'Adj Close': 10252.53027, 'Volume': 134600000.0, 'CloseUSD': 102.5253027}
# 241
# {'Index': '399001.SZ', 'Date': '2013-08-02', 'Open': 8023.72998, 'High': 8084.899902, 'Low': 7957.169922, 'Close': 7961.470215, 'Adj Close': 7961.380859, 'Volume': 117500.0, 'CloseUSD': 1273.8352344}
# 242
# {'Index': 'SSMI', 'Date': '1991-08-19', 'Open': 1723.5, 'High': 1723.5, 'Low': 1584.0, 'Close': 1587.400024, 'Adj Close': 1587.400024, 'Volume': 0.0, 'CloseUSD': 1762.01402664}
# 243
# ...
# 595
# {'Index': 'NSEI', 'Date': '2017-05-11', 'Open': 9448.599609, 'High': 9450.650391, 'Low': 9411.299805, 'Close': 9422.400391, 'Adj Close': 9422.400391, 'Volume': 171100.0, 'CloseUSD': 94.22400391}
# 596
# {'Index': '000001.SS', 'Date': '2008-01-31', 'Open': 4408.023926, 'High': 4487.317871, 'Low': 4368.295898, 'Close': 4383.393066, 'Adj Close': 4383.393066, 'Volume': 45200.0, 'CloseUSD': 701.34289056}
# 597
# {'Index': '000001.SS', 'Date': '2003-05-29', 'Open': 1549.052002, 'High': 1568.541992, 'Low': 1543.340942, 'Close': 1568.156006, 'Adj Close': 1568.156006, 'Volume': 14800.0, 'CloseUSD': 250.90496096}
# 598
# {'Index': 'IXIC', 'Date': '2019-06-05', 'Open': 7585.680176, 'High': 7589.470215, 'Low': 7498.169922, 'Close': 7575.47998, 'Adj Close': 7575.47998, 'Volume': 2115570000.0, 'CloseUSD': 7575.47998}
# 599
# {'Index': 'GSPTSE', 'Date': '2019-05-22', 'Open': 16345.79981, 'High': 16355.09961, 'Low': 16308.79981, 'Close': 16327.40039, 'Adj Close': 16327.40039, 'Volume': 19746430000.0, 'CloseUSD': 13551.7423237}
# 600
# {'Index': 'GSPTSE', 'Date': '2009-01-21', 'Open': 8574.5, 'High': 8763.5, 'Low': 8392.099609, 'Close': 8757.900391, 'Adj Close': 8757.900391, 'Volume': 24597110000.0, 'CloseUSD': 7269.057324529999}
# 601
# {'Index': 'NYA', 'Date': '1969-02-18', 'Open': 605.659973, 'High': 605.659973, 'Low': 605.659973, 'Close': 605.659973, 'Adj Close': 605.659973, 'Volume': 0.0, 'CloseUSD': 605.659973}
# 602
# {'Index': 'NSEI', 'Date': '2011-06-03', 'Open': 5565.700195, 'High': 5604.950195, 'Low': 5507.200195, 'Close': 5516.75, 'Adj Close': 5516.75, 'Volume': 0.0, 'CloseUSD': 55.1675}
# 603
# {'Index': 'NYA', 'Date': '2018-07-12', 'Open': 12746.71973, 'High': 12771.98047, 'Low': 12709.28027, 'Close': 12761.45996, 'Adj Close': 12761.45996, 'Volume': 2821690000.0, 'CloseUSD': 12761.45996}
# 604
# {'Index': 'GSPTSE', 'Date': '1982-11-01', 'Open': 1772.599976, 'High': 1790.699951, 'Low': 1771.699951, 'Close': 1790.699951, 'Adj Close': 1786.152588, 'Volume': 0.0, 'CloseUSD': 1486.28095933}
# 605
# {'Index': 'NYA', 'Date': '1982-10-25', 'Open': 810.47998, 'High': 810.47998, 'Low': 810.47998, 'Close': 810.47998, 'Adj Close': 810.47998, 'Volume': 0.0, 'CloseUSD': 810.47998}
# 606
# {'Index': 'GDAXI', 'Date': '2013-12-05', 'Open': 9110.530273, 'High': 9172.160156, 'Low': 9078.0, 'Close': 9084.950195, 'Adj Close': 9084.950195, 'Volume': 77772300.0, 'CloseUSD': 11083.6392379}
# 607
# {'Index': '399001.SZ', 'Date': '2006-12-05', 'Open': 5887.720215, 'High': 6005.529785, 'Low': 5860.339844, 'Close': 5928.029785, 'Adj Close': 5927.963379, 'Volume': 88000.0, 'CloseUSD': 948.4847656}
# 608
# {'Index': '000001.SS', 'Date': '2005-04-11', 'Open': 1248.150024, 'High': 1252.812988, 'Low': 1235.355957, 'Close': 1240.972046, 'Adj Close': 1240.972046, 'Volume': 19400.0, 'CloseUSD': 198.55552736}
# 609
# {'Index': 'GSPTSE', 'Date': '1980-05-13', 'Open': 1807.400024, 'High': 1830.5, 'Low': 1807.400024, 'Close': 1830.5, 'Adj Close': 1825.851563, 'Volume': 0.0, 'CloseUSD': 1519.3149999999998}
# 610
# {'Index': 'GDAXI', 'Date': '2019-03-12', 'Open': 11612.45996, 'High': 11618.73047, 'Low': 11499.46973, 'Close': 11524.16992, 'Adj Close': 11524.16992, 'Volume': 87365300.0, 'CloseUSD': 14059.4873024}
# 611
# {'Index': 'N225', 'Date': '2009-02-20', 'Open': 7544.069824, 'High': 7554.700195, 'Low': 7382.330078, 'Close': 7416.379883, 'Adj Close': 7416.379883, 'Volume': 140800000.0, 'CloseUSD': 74.16379883}
# 612
# {'Index': 'IXIC', 'Date': '1973-03-09', 'Open': 121.989998, 'High': 121.989998, 'Low': 121.989998, 'Close': 121.989998, 'Adj Close': 121.989998, 'Volume': 0.0, 'CloseUSD': 121.989998}
# 613
# {'Index': 'IXIC', 'Date': '1985-04-03', 'Open': 279.299988, 'High': 279.799988, 'Low': 277.5, 'Close': 277.899994, 'Adj Close': 277.899994, 'Volume': 77040000.0, 'CloseUSD': 277.899994}
# 614
# {'Index': 'GSPTSE', 'Date': '2003-02-28', 'Open': 6589.299805, 'High': 6618.399902, 'Low': 6548.899902, 'Close': 6555.100098, 'Adj Close': 6555.100098, 'Volume': 10170840000.0, 'CloseUSD': 5440.733081339999}
# 615
# {'Index': 'SSMI', 'Date': '2007-03-27', 'Open': 9053.0, 'High': 9058.0, 'Low': 8965.400391, 'Close': 8966.299805, 'Adj Close': 8966.299805, 'Volume': 60405400.0, 'CloseUSD': 9952.59278355}
# 616
# {'Index': 'IXIC', 'Date': '1990-06-27', 'Open': 454.299988, 'High': 457.100006, 'Low': 453.200012, 'Close': 456.899994, 'Adj Close': 456.899994, 'Volume': 137450000.0, 'CloseUSD': 456.899994}
# 617
# {'Index': 'HSI', 'Date': '1995-11-28', 'Open': 9542.5, 'High': 9628.200195, 'Low': 9542.5, 'Close': 9623.799805, 'Adj Close': 9623.799805, 'Volume': 0.0, 'CloseUSD': 1251.09397465}
# 618
# {'Index': 'IXIC', 'Date': '2003-01-27', 'Open': 1329.810059, 'High': 1349.829956, 'Low': 1320.319946, 'Close': 1325.27002, 'Adj Close': 1325.27002, 'Volume': 1440300000.0, 'CloseUSD': 1325.27002}
# 619
# {'Index': 'TWII', 'Date': '2013-07-11', 'Open': 8080.970215, 'High': 8179.540039, 'Low': 8080.970215, 'Close': 8179.540039, 'Adj Close': 8179.509277, 'Volume': 2724800.0, 'CloseUSD': 327.18160156000005}
# 620
# {'Index': 'HSI', 'Date': '1988-01-28', 'Open': 2406.699951, 'High': 2412.699951, 'Low': 2406.699951, 'Close': 2412.699951, 'Adj Close': 2412.699951, 'Volume': 0.0, 'CloseUSD': 313.65099363}
# 621
# {'Index': 'GSPTSE', 'Date': '2003-03-27', 'Open': 6345.399902, 'High': 6368.700195, 'Low': 6312.600098, 'Close': 6353.399902, 'Adj Close': 6353.399902, 'Volume': 11372860000.0, 'CloseUSD': 5273.32191866}
# 622
# {'Index': 'GSPTSE', 'Date': '1997-10-23', 'Open': 7053.100098, 'High': 7092.0, 'Low': 7046.399902, 'Close': 7073.799805, 'Adj Close': 7073.799805, 'Volume': 5938930000.0, 'CloseUSD': 5871.25383815}
# 623
# {'Index': 'IXIC', 'Date': '1989-03-02', 'Open': 400.5, 'High': 402.600006, 'Low': 400.0, 'Close': 402.5, 'Adj Close': 402.5, 'Volume': 129490000.0, 'CloseUSD': 402.5}
# 624
# {'Index': 'IXIC', 'Date': '2013-06-06', 'Open': 3404.409912, 'High': 3424.050049, 'Low': 3378.23999, 'Close': 3424.050049, 'Adj Close': 3424.050049, 'Volume': 1802700000.0, 'CloseUSD': 3424.050049}
# 625
# {'Index': 'N225', 'Date': '1970-02-18', 'Open': 2313.22998, 'High': 2313.22998, 'Low': 2313.22998, 'Close': 2313.22998, 'Adj Close': 2313.22998, 'Volume': 0.0, 'CloseUSD': 23.1322998}
# 626
# {'Index': 'N225', 'Date': '1989-06-28', 'Open': 33430.60938, 'High': 33430.60938, 'Low': 32952.01172, 'Close': 33245.60156, 'Adj Close': 33245.60156, 'Volume': 0.0, 'CloseUSD': 332.45601560000006}
# 627
# {'Index': '000001.SS', 'Date': '2009-12-02', 'Open': 3252.979004, 'High': 3278.27002, 'Low': 3245.964111, 'Close': 3269.750977, 'Adj Close': 3269.750977, 'Volume': 175000.0, 'CloseUSD': 523.16015632}
# 628
# {'Index': 'GSPTSE', 'Date': '1983-01-28', 'Open': 2020.900024, 'High': 2030.099976, 'Low': 2015.699951, 'Close': 2015.699951, 'Adj Close': 2010.581177, 'Volume': 0.0, 'CloseUSD': 1673.03095933}
# 629
# {'Index': 'N100', 'Date': '2006-11-06', 'Open': 927.530029, 'High': 935.02002, 'Low': 926.799988, 'Close': 935.02002, 'Adj Close': 935.02002, 'Volume': 273917300.0, 'CloseUSD': 1140.7244244}
# 630
# {'Index': 'IXIC', 'Date': '2016-01-21', 'Open': 4480.700195, 'High': 4537.149902, 'Low': 4432.02002, 'Close': 4472.060059, 'Adj Close': 4472.060059, 'Volume': 2447750000.0, 'CloseUSD': 4472.060059}
# 631
# {'Index': 'IXIC', 'Date': '2006-08-18', 'Open': 2157.139893, 'High': 2165.469971, 'Low': 2138.449951, 'Close': 2163.949951, 'Adj Close': 2163.949951, 'Volume': 1683790000.0, 'CloseUSD': 2163.949951}
# 632
# {'Index': '399001.SZ', 'Date': '2017-10-19', 'Open': 11275.30957, 'High': 11290.71973, 'Low': 11179.19043, 'Close': 11189.54981, 'Adj Close': 11189.50586, 'Volume': 96000.0, 'CloseUSD': 1790.3279696000002}
# 633
# {'Index': 'GDAXI', 'Date': '1993-07-07', 'Open': 1739.47998, 'High': 1739.47998, 'Low': 1739.47998, 'Close': 1739.47998, 'Adj Close': 1739.47998, 'Volume': 0.0, 'CloseUSD': 2122.1655756}
# 634
# {'Index': 'J203.JO', 'Date': '2018-04-12', 'Open': 56170.07031, 'High': 56651.0, 'Low': 55954.33984, 'Close': 56480.98047, 'Adj Close': 56480.98047, 'Volume': 0.0, 'CloseUSD': 3953.6686329}
# 635
# {'Index': 'TWII', 'Date': '2010-06-15', 'Open': 7388.569824, 'High': 7489.680176, 'Low': 7364.339844, 'Close': 7454.060059, 'Adj Close': 7454.032227, 'Volume': 2928800.0, 'CloseUSD': 298.16240236000004}
# 636
# {'Index': 'NYA', 'Date': '1971-05-13', 'Open': 598.469971, 'High': 598.469971, 'Low': 598.469971, 'Close': 598.469971, 'Adj Close': 598.469971, 'Volume': 0.0, 'CloseUSD': 598.469971}
# 637
# {'Index': 'SSMI', 'Date': '2020-08-27', 'Open': 10312.92969, 'High': 10331.42969, 'Low': 10240.45996, 'Close': 10240.45996, 'Adj Close': 10240.45996, 'Volume': 39229000.0, 'CloseUSD': 11366.9105556}
# 638
# {'Index': 'NSEI', 'Date': '2008-01-14', 'Open': 6208.799805, 'High': 6244.149902, 'Low': 6172.0, 'Close': 6206.799805, 'Adj Close': 6206.799805, 'Volume': 0.0, 'CloseUSD': 62.06799805}
# 639
# {'Index': 'N225', 'Date': '1992-01-07', 'Open': 23781.24023, 'High': 23901.89063, 'Low': 23514.2793, 'Close': 23566.39063, 'Adj Close': 23566.39063, 'Volume': 0.0, 'CloseUSD': 235.6639063}
# 640
# {'Index': 'IXIC', 'Date': '2020-08-28', 'Open': 11689.28027, 'High': 11708.76953, 'Low': 11634.76953, 'Close': 11695.62988, 'Adj Close': 11695.62988, 'Volume': 2997810000.0, 'CloseUSD': 11695.62988}
# 641
# {'Index': 'IXIC', 'Date': '1973-12-12', 'Open': 90.809998, 'High': 90.809998, 'Low': 90.809998, 'Close': 90.809998, 'Adj Close': 90.809998, 'Volume': 0.0, 'CloseUSD': 90.809998}
# 642
# {'Index': '000001.SS', 'Date': '2002-10-23', 'Open': 1549.765991, 'High': 1550.088013, 'Low': 1539.475952, 'Close': 1548.964966, 'Adj Close': 1548.964966, 'Volume': 0.0, 'CloseUSD': 247.83439456}
# 643
# {'Index': 'NSEI', 'Date': '2018-01-18', 'Open': 10873.40039, 'High': 10887.5, 'Low': 10782.40039, 'Close': 10817.0, 'Adj Close': 10817.0, 'Volume': 312000.0, 'CloseUSD': 108.17}
# 644
# {'Index': 'IXIC', 'Date': '1995-12-08', 'Open': 1056.430054, 'High': 1062.439941, 'Low': 1052.290039, 'Close': 1062.410034, 'Adj Close': 1062.410034, 'Volume': 455910000.0, 'CloseUSD': 1062.410034}
# 645
# {'Index': 'IXIC', 'Date': '2020-11-18', 'Open': 11896.05957, 'High': 11942.49023, 'Low': 11799.95996, 'Close': 11801.59961, 'Adj Close': 11801.59961, 'Volume': 4699160000.0, 'CloseUSD': 11801.59961}
# 646
# {'Index': '000001.SS', 'Date': '2005-06-06', 'Open': 1010.380981, 'High': 1034.853027, 'Low': 998.228027, 'Close': 1034.378052, 'Adj Close': 1034.378052, 'Volume': 11000.0, 'CloseUSD': 165.50048832000002}
# 647
# {'Index': 'HSI', 'Date': '1998-12-31', 'Open': 10117.05957, 'High': 10117.05957, 'Low': 10048.58008, 'Close': 10048.58008, 'Adj Close': 10048.58008, 'Volume': 0.0, 'CloseUSD': 1306.3154104}
# 648
# {'Index': 'GSPTSE', 'Date': '1997-09-11', 'Open': 6740.200195, 'High': 6743.299805, 'Low': 6705.799805, 'Close': 6741.899902, 'Adj Close': 6741.899902, 'Volume': 6163060000.0, 'CloseUSD': 5595.77691866}
# 649
# {'Index': 'NYA', 'Date': '1998-09-03', 'Open': 5179.959961, 'High': 5179.959961, 'Low': 5179.959961, 'Close': 5179.959961, 'Adj Close': 5179.959961, 'Volume': 0.0, 'CloseUSD': 5179.959961}
# 650
# {'Index': 'GDAXI', 'Date': '2013-04-15', 'Open': 7740.540039, 'High': 7773.109863, 'Low': 7651.580078, 'Close': 7712.629883, 'Adj Close': 7712.629883, 'Volume': 118152700.0, 'CloseUSD': 9409.40845726}
# 651
# {'Index': 'N225', 'Date': '2013-03-06', 'Open': 11811.05957, 'High': 11933.82031, 'Low': 11803.08984, 'Close': 11932.26953, 'Adj Close': 11932.26953, 'Volume': 200900000.0, 'CloseUSD': 119.3226953}
# 652
# {'Index': 'NYA', 'Date': '2006-07-27', 'Open': 8164.27002, 'High': 8231.019531, 'Low': 8134.910156, 'Close': 8144.859863, 'Adj Close': 8144.859863, 'Volume': 2776710000.0, 'CloseUSD': 8144.859863}
# 653
# {'Index': 'HSI', 'Date': '2012-06-29', 'Open': 18996.57031, 'High': 19510.76953, 'Low': 18991.09961, 'Close': 19441.46094, 'Adj Close': 19441.46094, 'Volume': 2039720800.0, 'CloseUSD': 2527.3899222}
# 654
# {'Index': 'GDAXI', 'Date': '1997-05-15', 'Open': 3574.570068, 'High': 3577.300049, 'Low': 3550.620117, 'Close': 3564.850098, 'Adj Close': 3564.850098, 'Volume': 0.0, 'CloseUSD': 4349.11711956}
# 655
# {'Index': '399001.SZ', 'Date': '2015-01-16', 'Open': 11496.75977, 'High': 11583.73047, 'Low': 11436.28027, 'Close': 11532.79981, 'Adj Close': 11532.6709, 'Volume': 242900.0, 'CloseUSD': 1845.2479696}
# 656
# {'Index': 'IXIC', 'Date': '1972-03-23', 'Open': 127.379997, 'High': 127.379997, 'Low': 127.379997, 'Close': 127.379997, 'Adj Close': 127.379997, 'Volume': 0.0, 'CloseUSD': 127.379997}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 for count, i in enumerate(consumer):
#       2     print(count)
#       3     print(i.value)
#
# File ~/anaconda3/lib/python3.11/site-packages/kafka/consumer/group.py:1193, in KafkaConsumer.__next__(self)
#    1191     return self.next_v1()
#    1192 else:
# -> 1193     return self.next_v2()
#
# File ~/anaconda3/lib/python3.11/site-packages/kafka/consumer/group.py:1201, in KafkaConsumer.next_v2(self)
#    1199     self._iterator = self._message_generator_v2()
#    1200 try:
# -> 1201     return next(self._iterator)
#    1202 except StopIteration:
#    1203     self._iterator = None
#
# File ~/anaconda3/lib/python3.11/site-packages/kafka/consumer/group.py:1116, in KafkaConsumer._message_generator_v2(self)
#    1114 def _message_generator_v2(self):
#    1115     timeout_ms = 1000 * (self._consumer_timeout - time.time())
# -> 1116     record_map = self.poll(timeout_ms=timeout_ms, update_offsets=False)
#    1117     for tp, records in six.iteritems(record_map):
#    1118         # Generators are stateful, and it is possible that the tp / records
#    1119         # here may become stale during iteration -- i.e., we seek to a
#    1120         # different offset, pause consumption, or lose assignment.
#    1121         for record in records:
#    1122             # is_fetchable(tp) should handle assignment changes and offset
#    1123             # resets; for all other changes (e.g., seeks) we'll rely on the
#    1124             # outer function destroying the existing iterator/generator
#    1125             # via self._iterator = None
#
# File ~/anaconda3/lib/python3.11/site-packages/kafka/consumer/group.py:655, in KafkaConsumer.poll(self, timeout_ms, max_records, update_offsets)
#     653 remaining = timeout_ms
#     654 while True:
# --> 655     records = self._poll_once(remaining, max_records, update_offsets=update_offsets)
#     656     if records:
#     657         return records
#
# File ~/anaconda3/lib/python3.11/site-packages/kafka/consumer/group.py:702, in KafkaConsumer._poll_once(self, timeout_ms, max_records, update_offsets)
#     699     self._client.poll(timeout_ms=0)
#     701 timeout_ms = min(timeout_ms, self._coordinator.time_to_next_poll() * 1000)
# --> 702 self._client.poll(timeout_ms=timeout_ms)
#     703 # after the long poll, we should check whether the group needs to rebalance
#     704 # prior to returning data so that the group can stabilize faster
#     705 if self._coordinator.need_rejoin():
#
# File ~/anaconda3/lib/python3.11/site-packages/kafka/client_async.py:602, in KafkaClient.poll(self, timeout_ms, future)
#     599             timeout = min(timeout, self.config['retry_backoff_ms'])
#     600         timeout = max(0, timeout)  # avoid negative timeouts
# --> 602     self._poll(timeout / 1000)
#     604 # called without the lock to avoid deadlock potential
#     605 # if handlers need to acquire locks
#     606 responses.extend(self._fire_pending_completed_requests())
#
# File ~/anaconda3/lib/python3.11/site-packages/kafka/client_async.py:634, in KafkaClient._poll(self, timeout)
#     631 self._register_send_sockets()
#     633 start_select = time.time()
# --> 634 ready = self._selector.select(timeout)
#     635 end_select = time.time()
#     636 if self._sensors:
#
# File ~/anaconda3/lib/python3.11/selectors.py:561, in KqueueSelector.select(self, timeout)
#     559 ready = []
#     560 try:
# --> 561     kev_list = self._selector.control(None, max_ev, timeout)
#     562 except InterruptedError:
#     563     return ready
#
# KeyboardInterrupt:

# %%
for count, i in enumerate(consumer):
    with s3.open("s3://kafka-stocket-market-proj-l/stock_market_{}.json".format(count), 'w') as file:
        json.dump(i.value, file)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 for count, i in enumerate(consumer):
#       2     with s3.open("s3://kafka-stocket-market-proj-l/stock_market_{}.json".format(count), 'w') as file:
#       3         json.dump(i.value, file)
#
# File ~/anaconda3/lib/python3.11/site-packages/kafka/consumer/group.py:1193, in KafkaConsumer.__next__(self)
#    1191     return self.next_v1()
#    1192 else:
# -> 1193     return self.next_v2()
#
# File ~/anaconda3/lib/python3.11/site-packages/kafka/consumer/group.py:1201, in KafkaConsumer.next_v2(self)
#    1199     self._iterator = self._message_generator_v2()
#    1200 try:
# -> 1201     return next(self._iterator)
#    1202 except StopIteration:
#    1203     self._iterator = None
#
# File ~/anaconda3/lib/python3.11/site-packages/kafka/consumer/group.py:1116, in KafkaConsumer._message_generator_v2(self)
#    1114 def _message_generator_v2(self):
#    1115     timeout_ms = 1000 * (self._consumer_timeout - time.time())
# -> 1116     record_map = self.poll(timeout_ms=timeout_ms, update_offsets=False)
#    1117     for tp, records in six.iteritems(record_map):
#    1118         # Generators are stateful, and it is possible that the tp / records
#    1119         # here may become stale during iteration -- i.e., we seek to a
#    1120         # different offset, pause consumption, or lose assignment.
#    1121         for record in records:
#    1122             # is_fetchable(tp) should handle assignment changes and offset
#    1123             # resets; for all other changes (e.g., seeks) we'll rely on the
#    1124             # outer function destroying the existing iterator/generator
#    1125             # via self._iterator = None
#
# File ~/anaconda3/lib/python3.11/site-packages/kafka/consumer/group.py:655, in KafkaConsumer.poll(self, timeout_ms, max_records, update_offsets)
#     653 remaining = timeout_ms
#     654 while True:
# --> 655     records = self._poll_once(remaining, max_records, update_offsets=update_offsets)
#     656     if records:
#     657         return records
#
# File ~/anaconda3/lib/python3.11/site-packages/kafka/consumer/group.py:702, in KafkaConsumer._poll_once(self, timeout_ms, max_records, update_offsets)
#     699     self._client.poll(timeout_ms=0)
#     701 timeout_ms = min(timeout_ms, self._coordinator.time_to_next_poll() * 1000)
# --> 702 self._client.poll(timeout_ms=timeout_ms)
#     703 # after the long poll, we should check whether the group needs to rebalance
#     704 # prior to returning data so that the group can stabilize faster
#     705 if self._coordinator.need_rejoin():
#
# File ~/anaconda3/lib/python3.11/site-packages/kafka/client_async.py:602, in KafkaClient.poll(self, timeout_ms, future)
#     599             timeout = min(timeout, self.config['retry_backoff_ms'])
#     600         timeout = max(0, timeout)  # avoid negative timeouts
# --> 602     self._poll(timeout / 1000)
#     604 # called without the lock to avoid deadlock potential
#     605 # if handlers need to acquire locks
#     606 responses.extend(self._fire_pending_completed_requests())
#
# File ~/anaconda3/lib/python3.11/site-packages/kafka/client_async.py:634, in KafkaClient._poll(self, timeout)
#     631 self._register_send_sockets()
#     633 start_select = time.time()
# --> 634 ready = self._selector.select(timeout)
#     635 end_select = time.time()
#     636 if self._sensors:
#
# File ~/anaconda3/lib/python3.11/selectors.py:561, in KqueueSelector.select(self, timeout)
#     559 ready = []
#     560 try:
# --> 561     kev_list = self._selector.control(None, max_ev, timeout)
#     562 except InterruptedError:
#     563     return ready
#
# KeyboardInterrupt:
